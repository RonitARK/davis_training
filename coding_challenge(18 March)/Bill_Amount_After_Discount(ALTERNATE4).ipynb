# %% [markdown]
# <a href="https://colab.research.google.com/github/RonitARK/Davis_Training/blob/main/coding_challenge(18%20March)/Bill_Amount_After_Discount(ALTERNATE4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = float(input("Enter price: "))
discount_pct = float(input("Enter discount percentage: "))

discount_amount = price * (discount_pct / 100)
final_price = price - discount_amount
print(f"Final price after discount: {final_price}")
