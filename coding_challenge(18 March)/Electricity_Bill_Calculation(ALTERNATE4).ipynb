# %% [markdown]
# <a href="https://colab.research.google.com/github/RonitARK/Davis_Training/blob/main/coding_challenge(18%20March)/Electricity_Bill_Calculation(ALTERNATE4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
units = float(input("Enter units: "))
rate_per_unit = 5.0 # Assuming a flat rate of $5 per unit
total_bill = units * rate_per_unit
print(f"Total bill amount: ${total_bill}")
