# %% [markdown]
# <a href="https://colab.research.google.com/github/RonitARK/Davis_Training/blob/main/coding_challenge(18%20March)/Simple_Interest(ALTERNATE3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
calc_si = lambda p, r, t: (p * r * t) / 100

p, r, t = 1000, 5, 2 # Example static inputs
print(f"Simple Interest: {calc_si(p, r, t)}")
