# %% [markdown]
# <a href="https://colab.research.google.com/github/RonitARK/Davis_Training/blob/main/coding_challenge(18%20March)/Bill_Amount_After_Discount(ALTERNATE8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = float(input("Enter the price: "))
discount_percentage = float(input("Enter the discount percentage: "))

discount_amount = (discount_percentage / 100) * price
final_price = price - discount_amount

print(f"The final price after a {discount_percentage}% discount is: ${final_price:.2f}")
