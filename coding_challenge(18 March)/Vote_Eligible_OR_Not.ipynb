# %% [markdown]
# <a href="https://colab.research.google.com/github/RonitARK/Davis_Training/blob/main/coding_challenge(18%20March)/Vote_Eligible_OR_Not.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Check whether a person is eligible to vote.
#
# Input: Enter age
#
# Output: Eligible / Not Eligible

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
